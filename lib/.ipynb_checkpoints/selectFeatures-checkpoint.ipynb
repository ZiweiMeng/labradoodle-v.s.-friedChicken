# %% [markdown]
# # Plot Feature Sets and Compare

# %%
from sklearn.decomposition import PCA
import pandas as pd
import numpy as np
from time import time
import matplotlib.pylab as plt
# %matplotlib inline

# %% [markdown]
# ## SIFT features

# %%
features_path = '../data/sift_features.csv'
features = pd.read_csv(features_path).transpose()
labels = pd.read_csv('../data/labels.csv')
features['label'] = labels['V1'].tolist()
test_ids = pd.read_csv('../output/prediction_inceptionV3.csv')
test_ids = test_ids.image.tolist()
test_ids = [x.split('.')[0] for x in test_ids]
train_features = features.ix[~features.index.isin(test_ids),]
test_features = features.ix[features.index.isin(test_ids),]
start = time()
pca = PCA(n_components=2047)
pca.fit(train_features.ix[:,:-1].values)
end = time()
print('PCA decomposition time is %.4g s' % (end - start))
ratio = np.sum(pca.explained_variance_ratio_[:2])
print('First two features covers %.2g variation of original ones.' % ratio)
# Out:
# PCA decomposition time is 7.685 s
# First two features covers 0.11 variation of original ones.

# %%
ratio = np.sum(pca.explained_variance_ratio_)
ratio
# Out:
# 1.0000000000000002

# %%
sub_train_features = pca.fit_transform(train_features.ix[:,:-1].values)
labels = train_features['label'].tolist()

plt.scatter(sub_train_features[:,0],sub_train_features[:,1],c=labels,alpha=0.5)

# %%
sub_train_features.shape
# Out:
# (1600, 750)

# %%
sub_test_features = pca.fit_transform(test_features.ix[:,:-1].values)
labels = test_features['label'].tolist()
plt.scatter(sub_test_features[:,0],sub_test_features[:,1],c=labels,alpha=0.5)

# %%
ratio = np.sum(pca.explained_variance_ratio_)
print('New features covers %.4g variation of original ones.' % ratio)
# Out:
# New features covers 1 variation of original ones.

# %%
new_train = pd.DataFrame(sub_train_features)
new_train.index = train_features.index
#new_train['image'] = train_features.index.tolist()
new_test = pd.DataFrame(sub_test_features)
new_test.index = test_features.index
#new_test['image'] = test_features.index.tolist()
new_features = pd.concat([new_train,new_test])
new_df = new_features.sort_index()
new_df = new_df.transpose()
#new_df.columns = features.index
new_df.to_csv('../data/sift_features_1000.csv', index=False)

# %%
new_train.head()
# Out:
#                  0         1         2         3         4         5    \
# image_0001 -0.008292 -0.004319 -0.001880  0.002645 -0.002085  0.000700
# image_0002 -0.009253 -0.002979 -0.001745  0.003169 -0.000565  0.001294
# image_0003  0.002123 -0.004500  0.005372  0.003714 -0.007351 -0.000083
# image_0004 -0.010064 -0.006760 -0.004586  0.002974 -0.000522  0.000634
# image_0008 -0.001264 -0.011586  0.001542  0.004841  0.003376 -0.000843
#
#                  6         7         8         9      ...          990  \
# image_0001  0.000632  0.000176 -0.000297  0.001758    ...    -0.001331
# image_0002 -0.000462 -0.000033 -0.000942  0.000970    ...    -0.000300
# image_0003 -0.000644  0.002709 -0.000832  0.004194    ...    -0.001043
# image_0004  0.001124  0.000868  0.001436 -0.000419    ...     0.000211
# image_0008 -0.004929  0.004304 -0.002273  0.002488    ...    -0.000295
#
#                  991       992       993       994       995       996  \
# ...

# %%
new_df.head()
# Out:
#    image_0001  image_0002  image_0003  image_0004  image_0005  image_0006  \
# 0   -0.008292   -0.009253    0.002123   -0.010064   -0.000219    0.000353
# 1   -0.004319   -0.002979   -0.004500   -0.006760    0.002381   -0.001720
# 2   -0.001880   -0.001745    0.005372   -0.004586   -0.002065   -0.001490
# 3    0.002645    0.003169    0.003714    0.002974   -0.007848    0.001747
# 4   -0.002085   -0.000565   -0.007351   -0.000522    0.002830   -0.000617
#
#    image_0007  image_0008  image_0009  image_0010     ...      image_1991  \
# 0    0.006123   -0.001264   -0.002577    0.002527     ...        0.002930
# 1   -0.008275   -0.011586   -0.004370   -0.001966     ...        0.018265
# 2    0.002124    0.001542    0.000635   -0.005080     ...        0.002180
# 3   -0.001746    0.004841   -0.004608    0.000532     ...       -0.007634
# 4   -0.000280    0.003376   -0.003267   -0.004706     ...        0.006029
#
# ...

# %% [markdown]
# ## CNN features

# %%
features_path = '../data/cnn_features.csv'
features = pd.read_csv(features_path).transpose()
labels = pd.read_csv('../data/labels.csv')
features['label'] = labels['V1'].tolist()
test_ids = pd.read_csv('../output/prediction_inceptionV3.csv')
train_features = features.ix[~features.index.isin(test_ids.image),]
test_features = features.ix[features.index.isin(test_ids.image),]
start = time()
pca = PCA(n_components=150)
pca.fit(train_features.ix[:,:-1].values)
end = time()
print('PCA decomposition time is %.4g s' % (end - start))
ratio = np.sum(pca.explained_variance_ratio_)
print('New features covers %.2g variation of original ones.' % ratio)
# Out:
# PCA decomposition time is 1.094 s
# New features covers 0.97 variation of original ones.

# %%
sub_train_features = pca.transform(train_features.ix[:,:-1].values)
labels = train_features['label'].tolist()

plt.scatter(sub_train_features[:,0],sub_train_features[:,1],c=labels,alpha=0.5)

# %%
test_features.head()
# Out:
#                        0         1         2         3          4          5  \
# image_0005.jpg -0.403729 -0.317822  1.117489 -0.260693  31.622265  37.238338
# image_0006.jpg -0.403729 -0.366229  3.970275 -0.260693   6.084146  22.061163
# image_0007.jpg -0.403729  3.362290  5.357011 -0.260693  11.970096  25.263779
# image_0019.jpg -0.403729 -0.054564  6.627464 -0.260693  19.926878  23.959156
# image_0020.jpg -0.403729 -0.366229  5.537394 -0.260693  15.798639  22.839823
#
#                        6         7        8         9  ...        2039  \
# image_0005.jpg -0.497269 -0.596274 -0.30045 -0.318311  ...    1.846070
# image_0006.jpg  0.223297 -0.596274 -0.30045 -0.318311  ...    0.234035
# image_0007.jpg -0.483853 -0.596274 -0.30045 -0.318311  ...    0.402389
# image_0019.jpg  0.460238 -0.596274 -0.30045 -0.318311  ...    1.858466
# image_0020.jpg  4.393505 -0.596274 -0.30045 -0.318311  ...   -0.661440
#
# ...

# %%
sub_test_features = pca.transform(test_features.ix[:,:-1].values)
labels = test_features['label'].tolist()
plt.scatter(sub_test_features[:,0],sub_test_features[:,1],c=labels,alpha=0.5)

# %%
new_train = pd.DataFrame(sub_train_features)
new_train.index = train_features.index
#new_train['image'] = train_features.index.tolist()
new_test = pd.DataFrame(sub_test_features)
new_test.index = test_features.index
#new_test['image'] = test_features.index.tolist()
new_features = pd.concat([new_train,new_test])
new_df = new_features.sort_index()
new_df = new_df.transpose()
#new_df.columns = features.index
new_df.to_csv('../data/cnn_features_cnn150.csv', index=False)

# %%
new_df.head()
# Out:
#    image_0001.jpg  image_0002.jpg  image_0003.jpg  image_0004.jpg  \
# 0      -86.950727     -102.546596      -47.775922     -131.785243
# 1       34.537955       48.408191       49.452377       99.560013
# 2      -32.635153      -19.224483       14.214670      -24.874559
# 3       62.730904       25.806347      -20.619781       78.186946
# 4      -10.738785      -16.790324       70.267106       95.101548
#
#    image_0005.jpg  image_0006.jpg  image_0007.jpg  image_0008.jpg  \
# 0      129.886469      -49.215570      -82.983803      -93.488759
# 1       36.324653       -6.397160       87.368211       76.074269
# 2       44.421333        5.702644        9.021409       -4.230688
# 3       33.403517       11.486493        5.928178       -6.891704
# 4       31.414758      -54.855641      -31.810668      -28.812383
#
#    image_0009.jpg  image_0010.jpg       ...        image_1991.jpg  \
# 0      -27.960713      -51.659815       ...            122.504436
# ...

# %%
new_features.shape
# Out:
# (2000, 150)

# %%
new = new_df.transpose()

# %%
new.head()
# Out:
#                        0          1          2          3          4    \
# image_0001.jpg  -86.950727  34.537955 -32.635153  62.730904 -10.738785
# image_0002.jpg -102.546596  48.408191 -19.224483  25.806347 -16.790324
# image_0003.jpg  -47.775922  49.452377  14.214670 -20.619781  70.267106
# image_0004.jpg -131.785243  99.560013 -24.874559  78.186946  95.101548
# image_0005.jpg  129.886469  36.324653  44.421333  33.403517  31.414758
#
#                       5          6          7          8          9    \
# image_0001.jpg -33.736530 -25.743257  17.341195   5.050354 -14.461854
# image_0002.jpg -51.728568  -9.351233   7.189304   8.483828  11.745546
# image_0003.jpg -12.216097 -43.824148  22.752022 -23.783048 -15.324740
# image_0004.jpg  -5.084709  44.422779   5.626826   9.830599 -36.847786
# image_0005.jpg -12.846071 -65.395715   3.386587   3.398331 -18.906714
#
#                   ...          140       141       142       143       144  \
# ...

# %%
new['label'] = features['label'].tolist()

# %%
new.head()
# Out:
#                          0          1          2          3          4  \
# image_0001.jpg  -86.950727  34.537955 -32.635153  62.730904 -10.738785
# image_0002.jpg -102.546596  48.408191 -19.224483  25.806347 -16.790324
# image_0003.jpg  -47.775922  49.452377  14.214670 -20.619781  70.267106
# image_0004.jpg -131.785243  99.560013 -24.874559  78.186946  95.101548
# image_0005.jpg  129.886469  36.324653  44.421333  33.403517  31.414758
#
#                         5          6          7          8          9  ...    \
# image_0001.jpg -33.736530 -25.743257  17.341195   5.050354 -14.461854  ...
# image_0002.jpg -51.728568  -9.351233   7.189304   8.483828  11.745546  ...
# image_0003.jpg -12.216097 -43.824148  22.752022 -23.783048 -15.324740  ...
# image_0004.jpg  -5.084709  44.422779   5.626826   9.830599 -36.847786  ...
# image_0005.jpg -12.846071 -65.395715   3.386587   3.398331 -18.906714  ...
#
#                      141       142       143       144       145       146  \
# ...

# %%
new = new.ix[new.index.isin(test_ids.image),]
plt.scatter(new.values[:,0],new.values[:,1],c=new.label.tolist(),alpha=0.5)
